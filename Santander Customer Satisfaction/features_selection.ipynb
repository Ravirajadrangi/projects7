# %%
from sklearn.cross_validation import cross_val_score, ShuffleSplit
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import numpy as np
from sklearn import cross_validation
from sklearn.ensemble import RandomForestClassifier
import zipfile
import os
from math import log
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

sample_submission = pd.read_csv('./datasets/sample_submission.csv')
train_data = pd.read_csv('./datasets/train.csv')
test_data = pd.read_csv('./datasets/test.csv')

train_data.loc[train_data['var3']<0, 'var3'] = 0
test_data.loc[test_data['var3']<0, 'var3'] = 0

nuniques_train = train_data.drop(['ID','TARGET'], axis=1).apply(lambda x:x.nunique())
nuniques_test = test_data.drop(['ID'], axis=1).apply(lambda x:x.nunique())
nuniques = nuniques_train[nuniques_train<10].index.unique()
X_train = train_data.drop(np.append(nuniques, ['ID','TARGET']), axis=1).values
X_test = test_data.drop(np.append(nuniques, 'ID'), axis=1).values
y_train = train_data['TARGET'].values
id_test = test_data['ID']

# %%
X = train_data
X

# %%
names = train_data.columns.values
 
rf = RandomForestRegressor(n_estimators=100, n_jobs=4, max_depth=17)
scores = []
fields = []
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
print "Features sorted by their score:"
scores = sorted(zip(map(lambda x: round(x, 4), rf.feature_importances_), names), 
             reverse=True)
# Out:
# Features sorted by their score:

# %%
[y for x, y in scores if x>0.001]
# Out:
# ['num_op_var39_ult3',
#  'var3',
#  'ind_var24',
#  'num_var13_corto',
#  'num_var13_0',
#  'num_var13_largo',
#  'num_var12_0',
#  'num_var13_corto_0',
#  'ind_var40',
#  'num_var8',
#  'num_var13_largo_0',
#  'ind_var39_0',
#  'num_var12',
#  'ind_var37',
#  'ind_var25',
#  'ind_var13_medio',
#  'ind_var40_0',
#  'ind_var41',
#  'ind_var26',
#  'ID',
#  'ind_var33',
#  'ind_var12',
#  'var15',
#  'ind_var33_0',
#  'imp_op_var41_efect_ult3',
#  'ind_var13_corto_0',
#  'imp_op_var39_efect_ult3',
#  'ind_var41_0',
#  'ind_var24_0',
#  'ind_var6_0',
#  'imp_op_var41_efect_ult1',
#  'num_var14_0',
#  'num_var13',
#  'imp_op_var41_comer_ult1',
#  'imp_op_var40_ult1',
#  'imp_op_var39_efect_ult1',
#  'ind_var12_0',
#  'imp_op_var41_comer_ult3',
#  'num_var1_0',
#  'ind_var13_corto',
#  'imp_op_var41_ult1',
#  'ind_var13',
#  'ind_var6',
#  'ind_var5',
#  'ind_var2',
#  'num_var1',
#  'ind_var44_0',
#  'imp_op_var39_comer_ult1',
#  'imp_ent_var16_ult1',
#  'num_var6',
#  'ind_var8',
#  'num_var5_0',
#  'ind_var37_0',
#  'ind_var39',
#  'ind_var13_largo_0',
#  'num_var6_0',
#  'num_var4',
#  'ind_var46',
#  'imp_op_var39_ult1',
#  'ind_var13_largo',
#  'num_var5',
#  'num_var13_medio',
#  'num_var13_medio_0',
#  'ind_var31_0',
#  'num_var8_0',
#  'num_var24_0',
#  'ind_var20']

# %%
scores
# Out:
# [(0.3956, 'num_op_var39_ult3'),
#  (0.1634, 'var3'),
#  (0.0413, 'ind_var24'),
#  (0.0326, 'num_var13_corto'),
#  (0.0288, 'num_var13_0'),
#  (0.0282, 'num_var13_largo'),
#  (0.025, 'num_var12_0'),
#  (0.0228, 'num_var13_corto_0'),
#  (0.0188, 'ind_var40'),
#  (0.0172, 'num_var8'),
#  (0.0149, 'num_var13_largo_0'),
#  (0.0147, 'ind_var39_0'),
#  (0.0128, 'num_var12'),
#  (0.0106, 'ind_var37'),
#  (0.01, 'ind_var25'),
#  (0.0098, 'ind_var13_medio'),
#  (0.0088, 'ind_var40_0'),
#  (0.0077, 'ind_var41'),
#  (0.0063, 'ind_var26'),
#  (0.0057, 'ID'),
#  (0.0051, 'ind_var33'),
#  (0.0047, 'ind_var12'),
#  (0.0044, 'var15'),
#  (0.0044, 'ind_var33_0'),
#  (0.0044, 'imp_op_var41_efect_ult3'),
#  (0.0043, 'ind_var13_corto_0'),
#  (0.0039, 'imp_op_var39_efect_ult3'),
#  (0.0034, 'ind_var41_0'),
#  (0.0034, 'ind_var24_0'),
#  (0.003, 'ind_var6_0'),
#  (0.0029, 'imp_op_var41_efect_ult1'),
#  (0.0028, 'num_var14_0'),
#  (0.0028, 'num_var13'),
#  (0.0028, 'imp_op_var41_comer_ult1'),
#  (0.0027, 'imp_op_var40_ult1'),
#  (0.0027, 'imp_op_var39_efect_ult1'),
#  (0.0026, 'ind_var12_0'),
#  (0.0025, 'imp_op_var41_comer_ult3'),
#  (0.0024, 'num_var1_0'),
#  (0.0024, 'ind_var13_corto'),
#  (0.0024, 'imp_op_var41_ult1'),
#  (0.0023, 'ind_var13'),
#  (0.0022, 'ind_var6'),
#  (0.0022, 'ind_var5'),
#  (0.0021, 'ind_var2'),
#  (0.002, 'num_var1'),
#  (0.002, 'ind_var44_0'),
#  (0.002, 'imp_op_var39_comer_ult1'),
#  (0.002, 'imp_ent_var16_ult1'),
#  (0.0019, 'num_var6'),
#  (0.0019, 'ind_var8'),
#  (0.0018, 'num_var5_0'),
#  (0.0018, 'ind_var37_0'),
#  (0.0017, 'ind_var39'),
#  (0.0017, 'ind_var13_largo_0'),
#  (0.0016, 'num_var6_0'),
#  (0.0015, 'num_var4'),
#  (0.0015, 'ind_var46'),
#  (0.0015, 'imp_op_var39_ult1'),
#  (0.0014, 'ind_var13_largo'),
#  (0.0013, 'num_var5'),
#  (0.0013, 'num_var13_medio'),
#  (0.0012, 'num_var13_medio_0'),
#  (0.0012, 'ind_var31_0'),
#  (0.0011, 'num_var8_0'),
#  (0.0011, 'num_var24_0'),
#  (0.0011, 'ind_var20'),
#  (0.0008, 'num_var17_0'),
#  (0.0008, 'ind_var8_0'),
#  (0.0007, 'num_var14'),
#  (0.0007, 'ind_var5_0'),
#  (0.0007, 'ind_var17'),
#  (0.0007, 'ind_var14_0'),
#  (0.0007, 'imp_op_var40_comer_ult3'),
#  (0.0006, 'ind_var34'),
#  (0.0006, 'ind_var18_0'),
#  (0.0005, 'num_var18_0'),
#  (0.0004, 'num_var20'),
#  (0.0004, 'num_var18'),
#  (0.0004, 'ind_var26_0'),
#  (0.0004, 'ind_var14'),
#  (0.0002, 'num_var20_0'),
#  (0.0002, 'num_var17'),
#  (0.0002, 'ind_var44'),
#  (0.0002, 'ind_var32_0'),
#  (0.0002, 'ind_var32'),
#  (0.0002, 'ind_var27'),
#  (0.0002, 'ind_var25_cte'),
#  (0.0002, 'ind_var20_0'),
#  (0.0002, 'ind_var17_0'),
#  (0.0002, 'imp_op_var40_efect_ult1'),
#  (0.0002, 'imp_op_var39_comer_ult3'),
#  (0.0001, 'ind_var37_cte'),
#  (0.0001, 'ind_var2_0'),
#  (0.0001, 'ind_var29_0'),
#  (0.0001, 'ind_var28'),
#  (0.0001, 'ind_var27_0'),
#  (0.0001, 'ind_var25_0'),
#  (0.0001, 'ind_var1_0'),
#  (0.0001, 'ind_var13_medio_0'),
#  (0.0001, 'ind_var13_0'),
#  (0.0001, 'ind_var1'),
#  (0.0001, 'imp_sal_var16_ult1'),
#  (0.0001, 'imp_op_var40_efect_ult3'),
#  (0.0001, 'imp_op_var40_comer_ult1'),
#  (0.0, 'num_var26_0'),
#  (0.0, 'num_var26'),
#  (0.0, 'num_var25_0'),
#  (0.0, 'num_var25'),
#  (0.0, 'num_var24'),
#  (0.0, 'num_op_var41_ult3'),
#  (0.0, 'num_op_var41_ult1'),
#  (0.0, 'num_op_var41_hace3'),
#  (0.0, 'num_op_var41_hace2'),
#  (0.0, 'num_op_var40_ult3'),
#  (0.0, 'num_op_var40_ult1'),
#  (0.0, 'num_op_var40_hace3'),
#  (0.0, 'num_op_var40_hace2'),
#  (0.0, 'num_op_var39_ult1'),
#  (0.0, 'num_op_var39_hace3'),
#  (0.0, 'num_op_var39_hace2'),
#  (0.0, 'ind_var46_0'),
#  (0.0, 'ind_var34_0'),
#  (0.0, 'ind_var32_cte'),
#  (0.0, 'ind_var31'),
#  (0.0, 'ind_var30_0'),
#  (0.0, 'ind_var30'),
#  (0.0, 'ind_var29'),
#  (0.0, 'ind_var28_0'),
#  (0.0, 'ind_var26_cte'),
#  (0.0, 'ind_var19'),
#  (0.0, 'ind_var18')]
